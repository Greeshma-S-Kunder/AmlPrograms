# %% [markdown]
# <a href="https://colab.research.google.com/github/Greeshma-S-Kunder/AmlPrograms/blob/main/Scikit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris = load_iris()
x = iris.data
y = iris.target

#test - size = 0.2 means 20% of the data is passed for testing remaining for training
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state = 42)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()

model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = model.predict(x_test)
print(pred)
# Out:
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0]

# %%
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score, confusion_matrix)

#evalution part
print("Accuracy : ", accuracy_score(y_test, pred))
print("Precision : ", precision_score(y_test, pred, average='weighted'))
print("Recall : ", recall_score(y_test, pred, average='weighted'))
print("F1 Score : ", f1_score(y_test, pred, average='weighted'))

#Confusion Matrix
print("Confusion Matrix")
print(confusion_matrix(y_test, pred))
# Out:
# Accuracy :  1.0
# Precision :  1.0
# Recall :  1.0
# F1 Score :  1.0
# Confusion Matrix
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]

# %%
#5 fold cross validation  - 1 data subset for testing and 4 data subset for training
#model verification once more after getting the result - just to validate the result

from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(model, x, y, cv=5, scoring = 'accuracy')
print("CV scores: " ,cv_scores)
print("Mean CV Accuarcy: ", cv_scores.mean())
# Out:
# CV scores:  [0.96666667 0.96666667 0.9        1.         1.        ]
# Mean CV Accuarcy:  0.9666666666666668

# %%
# breast cancer - 2 classes  - logistic regression
from sklearn.datasets import load_breast_cancer


cancer = load_breast_cancer()
x = cancer.data
y = cancer.target

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predict = model.predict(x_test)
print(predict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1361/4131713262.py in <cell line: 0>()
# ----> 1 predict = model.fit(x_test)
#       2 print(predict)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# TypeError: LogisticRegression.fit() missing 1 required positional argument: 'y'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_746/3618968493.py in <cell line: 0>()
# ----> 1 x
#
# NameError: name 'x' is not defined
